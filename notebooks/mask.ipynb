# %%
# convert segmented image to binary mask
# read segmented image.jpg
import cv2 
import numpy as np
import matplotlib.pyplot as plt
seg_img = cv2.imread('binary_mask.jpg')
plt.imshow(seg_img)

# %%
import cv2
import numpy as np

# Load the segmented image
segmented_image = cv2.imread('segmented_image.jpg')
plt.imshow(segmented_image)
